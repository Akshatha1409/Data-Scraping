# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

# %%
url="https://www.flipkart.com/search?q=iphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&page=1"
response = requests.get(url)
htmlcontent = response.content
soup = BeautifulSoup(htmlcontent,"html.parser")

# %%
data=soup.find_all('div',attrs={'class':'_2kHMtA'})

# %%
links=[]
products=[]
prices=[]
ratings=[]
start_link="https://www.flipkart.com"

# %%
for items in data:
    rest_link=items.find('a')['href']
    name=items.find('div',attrs={'class':'_4rR01T'})
    price=items.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
    rating=items.find('div',attrs={'class':'_3LWZlK'})
    products.append(name.text)
    prices.append(price.text)
    ratings.append(rating.text)
    links.append(start_link+rest_link)

# %%
print(products[1])
print(prices[1])
print(ratings[1])
print(links[1])
# Out:
# APPLE iPhone SE (Black, 128 GB)
# ₹32,299
# 4.5
# https://www.flipkart.com/apple-iphone-se-black-128-gb/p/itma9285ccc6af28?pid=MOBFWQ6BHUEVZPXD&lid=LSTMOBFWQ6BHUEVZPXDLYKD39&marketplace=FLIPKART&q=iphones&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=17ff6274-6ef1-4516-be28-fa43e2682565.MOBFWQ6BHUEVZPXD.SEARCH&ppt=None&ppn=None&ssid=je5x6o0e4w0000001645596767271&qH=3e7fa8c51e2e4986

# %%
df = pd.DataFrame({'Product Name':products,'Prices':prices,'Ratings':ratings,'Link':links})
df
# Out:
#                                          Product Name   Prices Ratings  \
# 0                 APPLE iPhone 12 Mini (Black, 64 GB)  ₹41,299     4.5
# 1                     APPLE iPhone SE (Black, 128 GB)  ₹32,299     4.5
# 2                APPLE iPhone 12 Mini (Purple, 64 GB)  ₹41,299     4.5
# 3                        APPLE iPhone SE (Red, 64 GB)  ₹29,299     4.5
# 4                       APPLE iPhone SE (Red, 128 GB)  ₹31,299     4.5
# 5                      APPLE iPhone SE (Black, 64 GB)  ₹29,299     4.5
# 6                     APPLE iPhone SE (White, 128 GB)  ₹32,299     4.5
# 7                      APPLE iPhone 12 (Black, 64 GB)  ₹53,999     4.7
# 8                 APPLE iPhone 12 Mini (White, 64 GB)  ₹41,299     4.5
# 9                      APPLE iPhone SE (White, 64 GB)  ₹29,299     4.5
# 10                 APPLE iPhone 12 Mini (Blue, 64 GB)  ₹41,299     4.5
# 11  Apple iPhone XR ((PRODUCT)RED, 64 GB) (Include...  ₹39,999     4.6
# ...

# %%
df.to_csv('iphones.csv', index=False, encoding='utf-8')
